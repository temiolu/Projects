# %%
import pandas as pd

# %%
data = [
    {'column1': 1, 'column2': 'a'},
    {'column1': 2, 'column2': 'b'},
    {'column1': 3, 'column2': 'c'}
]

# %%
pd.DataFrame(data)
# Out:
#    column1 column2
# 0        1       a
# 1        2       b
# 2        3       c

# %%
movies = pd.read_csv("moviedata.csv")

# %%
movies.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# ...

# %%
pd.set_option('display.max_rows', 20)

# %%
movies.dropna(inplace=True)

# %%
del movies['Poster_Link']

# %%
movies
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 990              Giù la testa          1971          PG  157 min
# 991            Kelly's Heroes          1970          GP  144 min
# 992           The Jungle Book          1967           U   78 min
# 994        A Hard Day's Night          1964           U   87 min
# 997     From Here to Eternity          1953      Passed  118 min
#
#                             Genre  IMDB_Rating  Meta_score  \
# 0                           Drama          9.3        80.0
# 1                    Crime, Drama          9.2       100.0
# ...

# %%
backup = movies

# %%
movies['Gross'] = movies['Gross'].str.replace(',',"")

# %%
movies['Gross'] = pd.to_numeric(movies['Gross'])

# %%
movies['No_of_Votes']
# Out:
# 0      2343110
# 1      1620367
# 2      2303232
# 3      1129952
# 4       689845
#         ...
# 990      30144
# 991      45338
# 992     166409
# 994      40351
# 997      43374
# Name: No_of_Votes, Length: 714, dtype: int64

# %%
movies.to_csv('moviedata.csv', index = False)

# %%
movies.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross              int64
# dtype: object

# %%
backup = movies.copy()

# %%
backup.loc[0, 'Series_Title'] = "Not the Same"

# %%
import re

# backup['Runtime'] = re.sub(r'\D', '', backup['Runtime'])
# backup['Runtime'] = [re.sub(r'\D', '', letters) for letters in backup['Runtime']]

# %%
# backup[~backup['Certificate'].str.contains('Passed')]
backup
# Out:
#                Series_Title Released_Year Certificate Runtime  \
# 0              Not the Same          1994           A     142
# 1             The Godfather          1972           A     175
# 2           The Dark Knight          2008          UA     152
# 3    The Godfather: Part II          1974           A     202
# 4              12 Angry Men          1957           U      96
# ..                      ...           ...         ...     ...
# 990            Giù la testa          1971          PG     157
# 991          Kelly's Heroes          1970          GP     144
# 992         The Jungle Book          1967           U      78
# 994      A Hard Day's Night          1964           U      87
# 997   From Here to Eternity          1953      Passed     118
#
#                             Genre IMDB_Rating Meta_score  \
# 0                           Drama         9.3       80.0
# 1                    Crime, Drama         9.2      100.0
# ...

# %%
movies['Runtime'] = pd.to_numeric(movies['Runtime'])

# %%
movies.to_csv('moviedata2.csv', index=False)
