# %%
import pandas as pd

# %%
airlineRoutes = pd.read_csv("USAirlinesRoutes.csv")
# Out:
# /var/folders/7h/cd9tnnys5h99grlb0130fvs80000gn/T/ipykernel_46775/2986945377.py:1: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   airlineRoutes = pd.read_csv("USAirlinesRoutes.csv")

# %%
airlineRoutes.head(1)
# Out:
#       Year  quarter               city1                          city2  \
# 5919  2010        1  Salt Lake City, UT  Tampa, FL (Metropolitan Area)
#
#      airport_1 airport_2  nsmiles  passengers    fare carrier_lg  large_ms  \
# 5919       SLC       TPA     1887         200  226.59         DL      0.38
#
#       fare_lg carrier_low  lf_ms  fare_low  \
# 5919   247.69          US    0.2    166.99
#
#                                     Geocoded_City1  \
# 5919  Salt Lake City, UT\n(40.758478, -111.888142)
#
#                                          Geocoded_City2
# 5919  Tampa, FL (Metropolitan Area)\n(37.8606, -78.8...

# %%
pd.set_option('display.max_rows', 25)

# %%
airlineRoutes.dropna(inplace=True)

# %%
airlineRoutes.dtypes
# Out:
# tbl                object
# Year                int64
# quarter             int64
# citymarketid_1      int64
# citymarketid_2      int64
# city1              object
# city2              object
# airportid_1         int64
# airportid_2         int64
# airport_1          object
# airport_2          object
# nsmiles             int64
# passengers          int64
# fare              float64
# carrier_lg         object
# large_ms          float64
# fare_lg           float64
# carrier_low        object
# lf_ms             float64
# fare_low          float64
# Geocoded_City1     object
# Geocoded_City2     object
# tbl1apk            object
# dtype: object

# %%
airlineRoutes
# Out:
#              tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 5919    Table 1a  2010        1           34614           33195
# 5920    Table 1a  1998        4           30189           31703
# 5921    Table 1a  1998        4           30198           30852
# 5922    Table 1a  2009        3           32211           32575
# 5923    Table 1a  1993        4           30255           30852
# ...          ...   ...      ...             ...             ...
# 222938   Table1a  2020        2           35412           33195
# 222939   Table1a  2020        2           31834           32575
# 222940   Table1a  2020        2           31834           32575
# 222941   Table1a  2020        2           31834           32575
# 222942   Table1a  2020        2           31834           32575
#
#                        city1                                  city2  \
# 5919      Salt Lake City, UT          Tampa, FL (Metropolitan Area)
# ...

# %%
del airlineRoutes['tbl1apk']

# %%
airlineRoutes
# Out:
#         Year  quarter                 city1  \
# 5919    2010        1    Salt Lake City, UT
# 5920    1998        4  Colorado Springs, CO
# 5921    1998        4        Pittsburgh, PA
# 5922    2009        3         Las Vegas, NV
# 5923    1993        4        Huntsville, AL
# ...      ...      ...                   ...
# 222938  2020        2         Knoxville, TN
# 222939  2020        2      Fayetteville, AR
# 222940  2020        2      Fayetteville, AR
# 222941  2020        2      Fayetteville, AR
# 222942  2020        2      Fayetteville, AR
#
#                                         city2 airport_1 airport_2  nsmiles  \
# 5919            Tampa, FL (Metropolitan Area)       SLC       TPA     1887
# 5920    New York City, NY (Metropolitan Area)       COS       HPN     1678
# 5921       Washington, DC (Metropolitan Area)       PIT       BWI      210
# 5922      Los Angeles, CA (Metropolitan Area)       LAS       SNA      236
# ...
